# %%
import requests
from bs4 import BeautifulSoup
import json
import random
from pymongo import MongoClient
import urllib
import sys
import datetime

# %%
mongo_client = MongoClient('localhost', 27017)

# %%
user_agents = [
    "Mozilla/5.0 (Windows NT 6.1; WOW64; rv:32.0)", "Mozilla/5.0 (Windows NT 6.1; Win64; x64)", "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko)"
    "Mozilla/5.0 (X11; CrOS i686 2268.111.0) AppleWebKit/536.11 (KHTML, like Gecko)", "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.6 (KHTML, like Gecko)", "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.6 (KHTML, like Gecko)",
    "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.1 (KHTML, like Gecko)", "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/536.5 (KHTML, like Gecko)", "Mozilla/5.0 (Windows NT 6.0) AppleWebKit/536.5 (KHTML, like Gecko)",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko)", "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/536.3 (KHTML, like Gecko)", "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0) AppleWebKit/536.3 (KHTML, like Gecko)",
    "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko)", "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko)", "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko)",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/536.3 (KHTML, like Gecko)", "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/536.3 (KHTML, like Gecko)", "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.3 (KHTML, like Gecko)",
]

# %%
ico_projects = ['Bitcoin', 'Ethereum', 'XRP', 'Bitcoin Cash', 'EOS', 'Stellar', 'Litecoin', 'Tether', 'Cardano', 
                'Monero', 'TRON', 'IOTA', 'Dash', 'Binance Coin', 'NEO', 'Ethereum Classic', 'NEM', 'Tezos', 'VeChain',
                'Dogecoin', 'Zcash', 'OmiseGO', 'Bitcoin Gold', 'Maker', 'Bytecoin', 'Ontology', 'Lisk', '0x','Decred',
                'Qtum', 'Bitcoin Diamond', 'BitShares', 'Nano', 'Zilliqa', 'Siacoin', 'DigiByte', 'ICON', 'Steem', 
                'Aeternity', 'Verge', 'Waves', 'Pundi X', 'Bytom', 'Electroneum', 'Basic Attention Token', 
                'Metaverse ETP', 'Holo', 'Stratis', 'Golem', 'Augur', 'Status', 'Populous', 'Komodo', 'TrueUSD', 
                'Chainlink', 'Waltonchain', 'Cryptonex', 'Ardor', 'Wanchain', 'Mithril', 'ReddCoin', 'KuCoin Shares',
                'IOST', 'MaidSafeCoin', 'ETERNAL TOKEN', 'HyperCash', 'MOAC', 'Aion', 'Aurora', 'Huobi Token', 'aelf',
                'Loopring', 'Bancor', 'DigixDAO', 'CyberMiles', 'GXChain', 'RChain', 'FunFair', 'Decentraland', 
                'Dropil', 'Dentacoin', 'QASH', 'Horizen', 'Nebulas', 'Ark', 'TenX', 'MonaCoin', 'Crypto.com', 
                'Theta Token', 'Nxt', 'Loom Network', 'Noah Coin', 'Power Ledger', 'WAX', 'Bitcoin Private', 
                'Mixin', 'PIVX', 'Elastos', 'Dai', 'Gas']

# %%
def insert_project(project_name,mongo_client):

    ## Insert in Databse 
    db = mongo_client.copernicus
    collection = db.blockchain_projects
    project_in_db = collection.find_one({"project": project_name})
    if project_in_db is None:
        collection.insert_one({"project": project_name})

# %%
for i in ico_projects[:20]:
    insert_project(i,mongo_client)

# %%
## Delete Blockchain project name from Database
def delete_project(project_name,mongo_client):

    ## Deleting from Database
    db = mongo_client.copernicus
    collection = db.blockchain_projects
    collection.delete_one({"project":project_name})

# %%
def get_access_token():
    
    data = {
        "grant_type":"client_credentials",
        "client_id":"wudREc7Zqge_iJgt30IyRWxldjmK1vo2",
        "client_secret":"DSVRoGaLT8umByUFJsVr73CxUGcNLboRZ6eA2mcC_Q30KERoo8JbM6AfJkBUi1We"
    }
    
    url = 'https://api.codeproject.com/token'
    try:
        re = requests.post(url, data=data, headers={'User-Agent': random.SystemRandom().choice(user_agents)})
        access_token = json.loads(re.text)['access_token']
        return access_token
    except Exception as e:
        print(e)
        sys.exit(1)

# %%
def get_data():
    access_token = get_access_token()
    mongo_client = MongoClient('localhost', 27017)
    db = mongo_client.copernicus
    projects_db = []
    projects_collection = db.blockchain_projects
    for project in projects_collection.find():
        projects_db.append(project['project'])
        
    ## Inserting project data to database 
    collection = db.codeproject_projects_reports
    
    for project in projects_db:
        query = project
        query = urllib.parse.quote_plus(query)
        url = 'https://api.codeproject.com/v1/Articles?tags=%s' %  query
        
        headers_get_posts = {
            "Authorization":"Bearer " + access_token,
            'User-Agent':random.SystemRandom().choice(user_agents)
        }
        
        try:
            response = requests.get(url, headers=headers_get_posts)
            result = json.loads(response.text)
            
            date = datetime.date.today().strftime ("%Y-%m-%d")
            project_in_db = collection.find_one({"project_name": project,"date":date})
            
            if project_in_db == None:
                collection.insert_one({'project_name': project, 'data': result['items'],'date':date})
            else:
                collection.update_one({'project_name': project}, {'$set': {'data': result['items']}})
        
        except Exception as e:
            print(e)
            sys.exit(1)

# %%
get_data()

# %%
url = 'https://api.codeproject.com/token'

# %%
re = requests.post(url, data=data, headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36'})

# %%
re
# Out:
# <Response [200]>

# %%
re.text
# Out:
# '{"access_token":"f7Z9Zbq2rXr0JFZyq4dEIdMGMyfu3EcTMsS7DxYLxGQ-fXr1jqixB2a_8p9_DfP5uehoJCF2uKrDh3mZnxvDMYwGRfoy8xqachXJyU8JZRSgiv0qdM8bKukgqFtKCNuexxQXYQgpedA4eQ1KEEJnNtWOpDTOafd-5fEunwILjnC2pwlYltsNmX6hGW7oZ4b9jgLYmVWw2dm56xxEuxOu7VKu013wSoA9Mq1gH4X9JZ6p-9riIh4XmAuEF_62tSgdIbPlABaPUuxawuhfxz6yapzEq-xK6FD42l5rGU74je7TWSf8cUnZEiquxyW4FQ2_dyg3sxeyUoOo0kbA13SLAAjrCGE","token_type":"bearer","expires_in":1209599}'

# %%
re.json()
# Out:
# {'access_token': 'f7Z9Zbq2rXr0JFZyq4dEIdMGMyfu3EcTMsS7DxYLxGQ-fXr1jqixB2a_8p9_DfP5uehoJCF2uKrDh3mZnxvDMYwGRfoy8xqachXJyU8JZRSgiv0qdM8bKukgqFtKCNuexxQXYQgpedA4eQ1KEEJnNtWOpDTOafd-5fEunwILjnC2pwlYltsNmX6hGW7oZ4b9jgLYmVWw2dm56xxEuxOu7VKu013wSoA9Mq1gH4X9JZ6p-9riIh4XmAuEF_62tSgdIbPlABaPUuxawuhfxz6yapzEq-xK6FD42l5rGU74je7TWSf8cUnZEiquxyW4FQ2_dyg3sxeyUoOo0kbA13SLAAjrCGE',
#  'expires_in': 1209599,
#  'token_type': 'bearer'}

# %%
json.loads(re.text)
# Out:
# {'access_token': 'f7Z9Zbq2rXr0JFZyq4dEIdMGMyfu3EcTMsS7DxYLxGQ-fXr1jqixB2a_8p9_DfP5uehoJCF2uKrDh3mZnxvDMYwGRfoy8xqachXJyU8JZRSgiv0qdM8bKukgqFtKCNuexxQXYQgpedA4eQ1KEEJnNtWOpDTOafd-5fEunwILjnC2pwlYltsNmX6hGW7oZ4b9jgLYmVWw2dm56xxEuxOu7VKu013wSoA9Mq1gH4X9JZ6p-9riIh4XmAuEF_62tSgdIbPlABaPUuxawuhfxz6yapzEq-xK6FD42l5rGU74je7TWSf8cUnZEiquxyW4FQ2_dyg3sxeyUoOo0kbA13SLAAjrCGE',
#  'expires_in': 1209599,
#  'token_type': 'bearer'}

# %%
access_token = json.loads(re.text)['access_token']

# %%
access_token
# Out:
# 'f7Z9Zbq2rXr0JFZyq4dEIdMGMyfu3EcTMsS7DxYLxGQ-fXr1jqixB2a_8p9_DfP5uehoJCF2uKrDh3mZnxvDMYwGRfoy8xqachXJyU8JZRSgiv0qdM8bKukgqFtKCNuexxQXYQgpedA4eQ1KEEJnNtWOpDTOafd-5fEunwILjnC2pwlYltsNmX6hGW7oZ4b9jgLYmVWw2dm56xxEuxOu7VKu013wSoA9Mq1gH4X9JZ6p-9riIh4XmAuEF_62tSgdIbPlABaPUuxawuhfxz6yapzEq-xK6FD42l5rGU74je7TWSf8cUnZEiquxyW4FQ2_dyg3sxeyUoOo0kbA13SLAAjrCGE'

# %%
url_get_posts = 'https://api.codeproject.com/v1/Articles?tags=bitcoin,ethereum,litecoin&page=1'

# %%
headers_get_posts = {
    "Authorization":"Bearer " + access_token,
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'
}

# %%
headers_get_posts
# Out:
# {'Authorization': 'Bearer f7Z9Zbq2rXr0JFZyq4dEIdMGMyfu3EcTMsS7DxYLxGQ-fXr1jqixB2a_8p9_DfP5uehoJCF2uKrDh3mZnxvDMYwGRfoy8xqachXJyU8JZRSgiv0qdM8bKukgqFtKCNuexxQXYQgpedA4eQ1KEEJnNtWOpDTOafd-5fEunwILjnC2pwlYltsNmX6hGW7oZ4b9jgLYmVWw2dm56xxEuxOu7VKu013wSoA9Mq1gH4X9JZ6p-9riIh4XmAuEF_62tSgdIbPlABaPUuxawuhfxz6yapzEq-xK6FD42l5rGU74je7TWSf8cUnZEiquxyW4FQ2_dyg3sxeyUoOo0kbA13SLAAjrCGE',
#  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'}

# %%
res = requests.get(url_get_posts,headers=headers_get_posts)

# %%
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '{"pagination":{"page":1,"pageSize":25,"totalPages":2,"totalItems":26},"items":[{"id":"2_1256008","title":"Etherdrop: DAPP Lottery on Ethereum Blockchain","authors":[{"name":"Fady Aro","id":7667955}],"summary":"Your Ethereum Giveaway Smart Contract Lottery","contentType":"Articles","docType":{"name":"article","id":1},"categories":[{"name":"general programming | blockchain | general","id":0}],"tags":[{"name":"javascript","id":87},{"name":"css","id":90},{"name":"html","id":104},{"name":"json","id":997},{"name":"web","id":1147},{"name":"npm","id":3812},{"name":"markdown","id":3875},{"name":"blockchain","id":4415},{"name":"ethereum","id":4512},{"name":"solidity","id":4667},{"name":"truffle","id":4668}],"license":{"name":"CPOL","id":0},"createdDate":"2018-08-10T22:50:00Z","modifiedDate":"2018-08-10T22:50:00Z","threadEditor":{"name":"Deeksha Shenoy","id":3866010},"threadModifiedDate":"2018-08-10T22:50:00Z","rating":4.818182,"votes":3,"popularity":2.385606,"websiteLink":"//www.codeproject.c
# ...

# %%
res.json()
# Out:
# {'items': [{'apiLink': '',
#    'authors': [{'id': 7667955, 'name': 'Fady Aro'}],
#    'categories': [{'id': 0,
#      'name': 'general programming | blockchain | general'}],
#    'contentType': 'Articles',
#    'createdDate': '2018-08-10T22:50:00Z',
#    'docType': {'id': 1, 'name': 'article'},
#    'id': '2_1256008',
#    'indentLevel': 0,
#    'license': {'id': 0, 'name': 'CPOL'},
#    'modifiedDate': '2018-08-10T22:50:00Z',
#    'parentId': 0,
#    'popularity': 2.385606,
#    'rating': 4.818182,
#    'summary': 'Your Ethereum Giveaway Smart Contract Lottery',
#    'tags': [{'id': 87, 'name': 'javascript'},
#     {'id': 90, 'name': 'css'},
#     {'id': 104, 'name': 'html'},
#     {'id': 997, 'name': 'json'},
#     {'id': 1147, 'name': 'web'},
#     {'id': 3812, 'name': 'npm'},
#     {'id': 3875, 'name': 'markdown'},
#     {'id': 4415, 'name': 'blockchain'},
#     {'id': 4512, 'name': 'ethereum'},
#     {'id': 4667, 'name': 'solidity'},
#     {'id': 4668, 'name': 'truffle'}],
# ...

# %%
content = res.json()

# %%
len(content['items'])
# Out:
# 25

# %%
'https:' + content['items'][0]['websiteLink']
# Out:
# 'https://www.codeproject.com/Articles/1256008/Etherdrop-DAPP-Lottery-on-Ethereum-Blockchain'

# %%
thread_urls = []
for item in content['items']:
    thread_urls.append("https:%s" % item['websiteLink'])

# %%
thread_urls
# Out:
# ['https://www.codeproject.com/Articles/1256008/Etherdrop-DAPP-Lottery-on-Ethereum-Blockchain',
#  'https://www.codeproject.com/Articles/1249874/Blockchain-Development-Part-Programming-Smart-Co',
#  'https://www.codeproject.com/Articles/1248309/Blockchain-Development-Part-Development-Environm',
#  'https://www.codeproject.com/Articles/1247306/Setting-up-Ethereum-Blockchain-on-Azure',
#  'https://www.codeproject.com/Articles/1240391/How-I-Hacked-Bitcoin-Mining-Pool',
#  'https://www.codeproject.com/Articles/1207351/Accepting-Bitcoin-BTC-payments-with-Csharp-ASP-NET',
#  'https://www.codeproject.com/Articles/1194406/Using-HttpClient-As-It-Was-Intended-Because-You-re',
#  'https://www.codeproject.com/Articles/1172340/Hashcash-or-Proof-of-Work',
#  'https://www.codeproject.com/Articles/1096320/HBitcoin-High-level-Csharp-Bitcoin-Wallet-Library',
#  'https://www.codeproject.com/Articles/1115639/Build-your-own-Bitcoin-wallet',
# ...

# %%
content['items'][0]
# Out:
# {'apiLink': '',
#  'authors': [{'id': 7667955, 'name': 'Fady Aro'}],
#  'categories': [{'id': 0,
#    'name': 'general programming | blockchain | general'}],
#  'contentType': 'Articles',
#  'createdDate': '2018-08-10T22:50:00Z',
#  'docType': {'id': 1, 'name': 'article'},
#  'id': '2_1256008',
#  'indentLevel': 0,
#  'license': {'id': 0, 'name': 'CPOL'},
#  'modifiedDate': '2018-08-10T22:50:00Z',
#  'parentId': 0,
#  'popularity': 2.385606,
#  'rating': 4.818182,
#  'summary': 'Your Ethereum Giveaway Smart Contract Lottery',
#  'tags': [{'id': 87, 'name': 'javascript'},
#   {'id': 90, 'name': 'css'},
#   {'id': 104, 'name': 'html'},
#   {'id': 997, 'name': 'json'},
#   {'id': 1147, 'name': 'web'},
#   {'id': 3812, 'name': 'npm'},
#   {'id': 3875, 'name': 'markdown'},
#   {'id': 4415, 'name': 'blockchain'},
#   {'id': 4512, 'name': 'ethereum'},
#   {'id': 4667, 'name': 'solidity'},
#   {'id': 4668, 'name': 'truffle'}],
#  'threadEditor': {'id': 3866010, 'name': 'Deeksha Shenoy'},
# ...

# %%
res_content = requests.get(thread_urls[0],headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'})

# %%
res_content.text
# Out:
# '<!DOCTYPE HTML>\r\n\r\n\r\n<html>\r\n<head>\r\n\t<title>Etherdrop: DAPP Lottery on Ethereum Blockchain - CodeProject</title> \r\n\t<link type="text/css" rel="stylesheet" href="https://codeproject.global.ssl.fastly.net/App_Themes/CodeProject/Css/Main.min.css?dt=2.8.180920.1">\r\n\r\n\t\r\n<meta http-equiv="content-language" content="en-US">\r\n<meta charset="UTF-8">\r\n<meta name="Description" content="Your Ethereum Giveaway Smart Contract Lottery; Author: Fady Aro; Updated: 10 Aug 2018; Section: Blockchain; Chapter: General Programming; Updated: 10 Aug 2018">\r\n<meta name="Keywords" content="Javascript, CSS, HTML, JSON, Web, NPM, Markdown, blockchain, Ethereum, Solidity, Truffle,Blockchain,General Programming,Free source code, tutorials">\r\n<meta name="Author" content="Fady Aro">\r\n<meta name="Rating" content="General">\r\n<meta name="Revisit-After" content="1 days">\r\n<meta name="application-name" content="CodeProject">\r\n<meta name="google-translate-customization" content="d9
# ...

# %%
new_text = res_content.text.replace('\n',"")

# %%
new_text = new_text.replace('\t',"")

# %%
new_text
# Out:
# '<!DOCTYPE HTML>\r\r\r<html>\r<head>\r<title>Etherdrop: DAPP Lottery on Ethereum Blockchain - CodeProject</title> \r<link type="text/css" rel="stylesheet" href="https://codeproject.global.ssl.fastly.net/App_Themes/CodeProject/Css/Main.min.css?dt=2.8.180920.1">\r\r\r<meta http-equiv="content-language" content="en-US">\r<meta charset="UTF-8">\r<meta name="Description" content="Your Ethereum Giveaway Smart Contract Lottery; Author: Fady Aro; Updated: 10 Aug 2018; Section: Blockchain; Chapter: General Programming; Updated: 10 Aug 2018">\r<meta name="Keywords" content="Javascript, CSS, HTML, JSON, Web, NPM, Markdown, blockchain, Ethereum, Solidity, Truffle,Blockchain,General Programming,Free source code, tutorials">\r<meta name="Author" content="Fady Aro">\r<meta name="Rating" content="General">\r<meta name="Revisit-After" content="1 days">\r<meta name="application-name" content="CodeProject">\r<meta name="google-translate-customization" content="d908bb7ce7aff658-4c2f3a504525c916-g629383f
# ...

# %%
bs = BeautifulSoup(new_text)

# %%
bs
# Out:
# <!DOCTYPE HTML>
# ...
